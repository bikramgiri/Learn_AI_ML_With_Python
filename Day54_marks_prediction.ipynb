# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import pandas as pd

# %%
df = pd.read_csv("Student_Marks.csv")

# %%
df.sample(10)
# Out:
#     number_courses  time_study   Marks
# 77               8       5.985  38.278
# 24               4       3.635  16.517
# 47               4       4.779  22.701
# 82               4       7.410  44.099
# 54               8       7.591  53.158
# 87               3       1.033   6.053
# 61               4       2.438  10.844
# 19               8       3.977  25.133
# 81               8       2.262  17.705
# 9                3       6.173  30.862

# %%
df.info
# Out:
# <bound method DataFrame.info of     number_courses  time_study   Marks
# 0                3       4.508  19.202
# 1                4       0.096   7.734
# 2                4       3.133  13.811
# 3                6       7.909  53.018
# 4                8       7.811  55.299
# ..             ...         ...     ...
# 95               6       3.561  19.128
# 96               3       0.301   5.609
# 97               4       7.163  41.444
# 98               7       0.309  12.027
# 99               3       6.335  32.357
#
# [100 rows x 3 columns]>

# %%
X = df.iloc[:, :-1]

# %%
X
# Out:
#     number_courses  time_study
# 0                3       4.508
# 1                4       0.096
# 2                4       3.133
# 3                6       7.909
# 4                8       7.811
# ..             ...         ...
# 95               6       3.561
# 96               3       0.301
# 97               4       7.163
# 98               7       0.309
# 99               3       6.335
#
# [100 rows x 2 columns]

# %%
Y = df.iloc[:, -1]

# %%
Y
# Out:
# 0     19.202
# 1      7.734
# 2     13.811
# 3     53.018
# 4     55.299
#        ...
# 95    19.128
# 96     5.609
# 97    41.444
# 98    12.027
# 99    32.357
# Name: Marks, Length: 100, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 42)

# %%
X_train
# Out:
#     number_courses  time_study
# 55               7       2.913
# 88               5       1.803
# 26               7       0.508
# 42               6       3.591
# 69               6       3.948
# ..             ...         ...
# 60               6       0.376
# 71               5       2.518
# 14               3       2.908
# 92               4       5.027
# 51               6       4.130
#
# [80 rows x 2 columns]

# %%
X_test
# Out:
#     number_courses  time_study
# 83               5       3.197
# 53               7       6.049
# 70               4       3.736
# 45               3       2.061
# 44               4       1.954
# 39               6       7.775
# 22               5       2.051
# 80               7       7.957
# 10               3       7.353
# 0                3       4.508
# 18               6       7.711
# 30               8       3.864
# 73               3       1.629
# 33               6       6.594
# 90               7       4.182
# 4                8       7.811
# 76               5       6.379
# 77               8       5.985
# 12               7       4.218
# 31               3       1.923

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
test_prediction = lr.predict(X_test)

# %%
accuracy = r2_score(Y_test, test_prediction)

# %%
print(f"Accuracy = {accuracy * 100:.5f}%")
# Out:
# Accuracy = 94.59936%

# %%
no_of_courses = 5
no_of_hours_studied = 5

# %%
val = [[no_of_courses, no_of_hours_studied]]

# %%
prediction = lr.predict(val)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print(prediction)
# Out:
# [28.59406151]
