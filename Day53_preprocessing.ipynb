# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %% [markdown]
# Convert YearBuilt into Age of the House

# %%
df = pd.read_csv('House Price Prediction Dataset.csv')
df.sample(10)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 1481  1482   852         1          3       1       1990  Suburban       Good
# 701    702  2475         2          4       1       1998     Rural  Excellent
# 1022  1023   540         2          4       1       1906     Urban  Excellent
# 1714  1715  2859         4          4       1       1912     Rural       Poor
# 1651  1652  3647         3          2       3       2004     Urban       Fair
# 1189  1190   510         3          1       1       1992     Rural       Good
# 1737  1738  3773         1          1       3       1942  Suburban       Poor
# 586    587  2074         1          3       1       1934     Rural       Fair
# 325    326  2193         4          4       2       2016     Rural       Fair
# 1938  1939  2885         5          3       2       1990     Urban       Poor
#
#      Garage   Price
# 1481     No  874254
# 701     Yes  978671
# 1022    Yes  640846
# 1714     No  332154
# 1651     No  817018
# 1189    Yes  466981
# 1737    Yes  744896
# 586      No  909299
# 325     Yes  822793
# 1938     No  757508

# %%
df["Age"] = 2025 - df["YearBuilt"]
df.drop("YearBuilt", axis=1, inplace=True)

# %%
df.sample(3)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors Location Condition Garage  \
# 1960  1961   892         2          3       1    Urban      Fair     No
# 1687  1688  1514         1          2       2    Rural      Poor     No
# 1036  1037  3528         4          2       2    Urban      Poor    Yes
#
#        Price  Age
# 1960  279333   83
# 1687  247977   26
# 1036  797146  115

# %%
condition_encoder = OrdinalEncoder(categories=[['Poor', 'Fair', 'Good', 'Excellent']])
df[['Condition']] = condition_encoder.fit_transform(df[['Condition']])

# %%
df.head(10)
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  Location  Condition Garage   Price  \
# 0   1  1360         5          4       3  Downtown        3.0     No  149919
# 1   2  4272         5          4       3  Downtown        3.0     No  424998
# 2   3  3592         2          2       3  Downtown        2.0     No  266746
# 3   4   966         4          2       2  Suburban        1.0    Yes  244020
# 4   5  4926         1          4       2  Downtown        1.0    Yes  636056
# 5   6  3944         1          2       1     Urban        0.0     No   93262
# 6   7  3671         1          1       2     Rural        0.0    Yes  448722
# 7   8  3419         2          4       1  Suburban        2.0    Yes  594893
# 8   9   630         2          2       1     Rural        0.0    Yes  652878
# 9  10  2185         3          3       1  Downtown        0.0     No  340375
#
#    Age
# 0   55
# 1   67
# 2   87
# 3  123
# 4   50
# 5  119
# 6   77
# 7  100
# 8   93
# 9   25

# %% [markdown]
# One-Hot Encoding: Garage

# %%
ohe = OneHotEncoder(drop = None, sparse_output=False)
garage_encoded = ohe.fit_transform(df[['Garage']])

garage_cols = ohe.get_feature_names_out(['Garage'])
garage_df = pd.DataFrame(garage_encoded, columns = garage_cols, index = df.index)
df.drop("Garage", axis=1, inplace=True)
df = pd.concat([df, garage_df], axis=1)

# %%
df.sample(4)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  Location  Condition   Price  \
# 1540  1541  4896         4          1       2  Downtown        2.0  782320
# 852    853   845         4          1       3  Suburban        3.0  168194
# 375    376  3339         1          4       1     Rural        0.0  981767
# 495    496  1743         5          2       3  Suburban        0.0  591285
#
#       Age  Garage_No  Garage_Yes
# 1540   71        0.0         1.0
# 852    97        1.0         0.0
# 375     8        1.0         0.0
# 495   105        0.0         1.0

# %% [markdown]
# One-Hot Encoding: Location

# %%
ohe = OneHotEncoder(drop = None, sparse_output=False)
location_encoded = ohe.fit_transform(df[['Location']])

location_cols = ohe.get_feature_names_out(['Location'])
location_df = pd.DataFrame(location_encoded, columns = location_cols, index = df.index)
df.drop("Location", axis=1, inplace=True)
df = pd.concat([df, location_df], axis=1)

# %%
df.sample(4)
# Out:
#         Id  Area  Bedrooms  Bathrooms  Floors  Condition   Price  Age  \
# 511    512   633         3          1       1        2.0  417390    4
# 1963  1964  4131         1          3       2        3.0  923055  120
# 1957  1958  4700         3          3       1        2.0  253426  108
# 1059  1060  2262         1          1       2        1.0  805247   48
#
#       Garage_No  Garage_Yes  Location_Downtown  Location_Rural  \
# 511         0.0         1.0                0.0             0.0
# 1963        1.0         0.0                0.0             0.0
# 1957        0.0         1.0                0.0             1.0
# 1059        1.0         0.0                0.0             0.0
#
#       Location_Suburban  Location_Urban
# 511                 0.0             1.0
# 1963                1.0             0.0
# 1957                0.0             0.0
# 1059                1.0             0.0

# %%
df.drop("Id", axis=1, inplace=True)
df.sample(4)
# Out:
#       Area  Bedrooms  Bathrooms  Floors  Condition   Price  Age  Garage_No  \
# 1157  4011         4          3       1        2.0  540533  104        1.0
# 147   3652         4          3       3        1.0  128038   82        1.0
# 1363  3880         1          1       2        0.0  901612    6        1.0
# 1046   648         4          3       2        0.0  375969   20        1.0
#
#       Garage_Yes  Location_Downtown  Location_Rural  Location_Suburban  \
# 1157         0.0                0.0             0.0                1.0
# 147          0.0                0.0             0.0                0.0
# 1363         0.0                1.0             0.0                0.0
# 1046         0.0                1.0             0.0                0.0
#
#       Location_Urban
# 1157             0.0
# 147              1.0
# 1363             0.0
# 1046             0.0

# %%
price_col = df.pop("Price")
df["Price"] = price_col

# %%
df.sample(4)
# Out:
#       Area  Bedrooms  Bathrooms  Floors  Condition  Age  Garage_No  \
# 671    864         2          4       3        2.0   69        0.0
# 1735  4645         5          2       2        2.0   82        1.0
# 1422  2209         1          4       1        2.0  121        1.0
# 489   4686         3          1       2        1.0    8        0.0
#
#       Garage_Yes  Location_Downtown  Location_Rural  Location_Suburban  \
# 671          1.0                0.0             1.0                0.0
# 1735         0.0                1.0             0.0                0.0
# 1422         0.0                1.0             0.0                0.0
# 489          1.0                0.0             0.0                1.0
#
#       Location_Urban   Price
# 671              0.0  201958
# 1735             0.0  502669
# 1422             0.0  987126
# 489              0.0  431965

# %%
df.to_csv("PreProcessed_Data.csv", index = False)
