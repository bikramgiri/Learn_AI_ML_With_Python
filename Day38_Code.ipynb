# %%
import pandas as pd
import matplotlib.pyplot as plt
# Or
# from matplotlib import pyplot as plt

# %%
plt.style.use('fivethirtyeight')

# %%
data = pd.read_csv("Data.csv")
data
# Out:
#      view_count    likes  ratio
# 0       8036001   324742  96.91
# 1       9378067   562589  98.19
# 2       2182066   273650  99.38
# 3       6525864    94698  96.25
# 4       9481284   582481  97.22
# ..          ...      ...    ...
# 195     1069693     3970  90.66
# 196      590760    70454  99.18
# 197      319347     1208  92.50
# 198    27594927  1351963  96.40
# 199    26993425   437561  97.42
#
# [200 rows x 3 columns]

# %%
view_count = data['view_count']
likes = data['likes']
ratio = data['ratio']

# %%
view_count
# Out:
# 0       8036001
# 1       9378067
# 2       2182066
# 3       6525864
# 4       9481284
#          ...
# 195     1069693
# 196      590760
# 197      319347
# 198    27594927
# 199    26993425
# Name: view_count, Length: 200, dtype: int64

# %%
likes
# Out:
# 0       324742
# 1       562589
# 2       273650
# 3        94698
# 4       582481
#         ...
# 195       3970
# 196      70454
# 197       1208
# 198    1351963
# 199     437561
# Name: likes, Length: 200, dtype: int64

# %%
ratio
# Out:
# 0      96.91
# 1      98.19
# 2      99.38
# 3      96.25
# 4      97.22
#        ...
# 195    90.66
# 196    99.18
# 197    92.50
# 198    96.40
# 199    97.42
# Name: ratio, Length: 200, dtype: float64

# %%
plt.scatter(view_count, likes, c = ratio, cmap = "summer", alpha = 0.8, edgecolors = "black", linewidth = 0.7)

cbar = plt.colorbar()
cbar.set_label("Like to Dislike Ratio")

plt.xscale("log")
plt.yscale("log")

plt.xlabel("View Count")
plt.ylabel("Total Likes")
plt.title("Trending YouTube Videos")

plt.tight_layout()
plt.show()
